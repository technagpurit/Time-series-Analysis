# %%
import numpy as np

from pandas import read_csv

TS=read_csv('newdataset.csv')

# %%
TS
# Out:
#      values
# 0       1.3
# 1       1.2
# 2       1.2
# 3       1.2
# 4       1.2
# ..      ...
# 295     1.8
# 296     1.8
# 297     1.7
# 298     1.7
# 299     1.7
#
# [300 rows x 1 columns]

# %%
# -*- coding: utf-8 -*-
"""Untitled24.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1JggIkAknS-upHbTHmWSKF9cDO_V-TNvv
"""

import numpy as np

from pandas import read_csv

TS=read_csv('newdataset.csv')

data = TS.values

emd = EMD()

from pandas import read_csv

TS=read_csv('newdataset.csv')

data=TS.values

d1=np.reshape(data,(300,))

d1.shape

import pylab as plt

from PyEMD import EMD, Visualisation

emd.emd(d1)

imfs, res = emd.get_imfs_and_residue()

vis = Visualisation()

vis.plot_imfs(imfs=imfs, residue=res, t=t, include_residue=True)
vis.plot_instant_freq(t, imfs=imfs)
vis.show()



from PyEMD import EEMD

if __name__ == "__main__":
    eemd = EEMD()
    eIMFs = eemd(d1)

eimfs, res = eemd.get_imfs_and_residue()

vis.plot_imfs(imfs=eimfs, residue=res, t=t, include_residue=True)
vis.plot_instant_freq(t, imfs=imfs)
vis.show()

from PyEMD import CEEMDAN

ceemdan = CEEMDAN()

cIMFs = ceemdan(d1)

vis.plot_imfs(imfs=cIMFs, residue=res, t=t, include_residue=True)
vis.plot_instant_freq(t, imfs=imfs)
vis.show()

t = np.arange(0, 3, 0.01)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 40
#      36 imfs, res = emd.get_imfs_and_residue()
#      38 vis = Visualisation()
# ---> 40 vis.plot_imfs(imfs=imfs, residue=res, t=t, include_residue=True)
#      41 vis.plot_instant_freq(t, imfs=imfs)
#      42 vis.show()
#
# NameError: name 't' is not defined

# %%
TS
# Out:
#      1.3
# 0    1.2
# 1    1.2
# 2    1.2
# 3    1.2
# 4    1.1
# ..   ...
# 294  1.8
# 295  1.8
# 296  1.7
# 297  1.7
# 298  1.7
#
# [299 rows x 1 columns]

# %%
# -*- coding: utf-8 -*-


data = TS.values

emd = EMD()

from pandas import read_csv

TS=read_csv('newdataset.csv')

data=TS.values

d1=np.reshape(data,(299,))

d1.shape

import pylab as plt

from PyEMD import EMD, Visualisation

emd.emd(d1)

imfs, res = emd.get_imfs_and_residue()

vis = Visualisation()

vis.plot_imfs(imfs=imfs, residue=res, t=t, include_residue=True)
vis.plot_instant_freq(t, imfs=imfs)
vis.show()



from PyEMD import EEMD

if __name__ == "__main__":
    eemd = EEMD()
    eIMFs = eemd(d1)

eimfs, res = eemd.get_imfs_and_residue()

vis.plot_imfs(imfs=eimfs, residue=res, t=t, include_residue=True)
vis.plot_instant_freq(t, imfs=imfs)
vis.show()

from PyEMD import CEEMDAN

ceemdan = CEEMDAN()

cIMFs = ceemdan(d1)

vis.plot_imfs(imfs=cIMFs, residue=res, t=t, include_residue=True)
vis.plot_instant_freq(t, imfs=imfs)
vis.show()

t = np.arange(0, 3, 0.01)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 28
#      24 imfs, res = emd.get_imfs_and_residue()
#      26 vis = Visualisation()
# ---> 28 vis.plot_imfs(imfs=imfs, residue=res, t=t, include_residue=True)
#      29 vis.plot_instant_freq(t, imfs=imfs)
#      30 vis.show()
#
# NameError: name 't' is not defined

# %%
import pylab as plt

from PyEMD import EMD, Visualisation

emd.emd(d1)

imfs, res = emd.get_imfs_and_residue()

vis = Visualisation()

vis.plot_imfs(imfs=imfs, residue=res, t=t, include_residue=True)
vis.plot_instant_freq(t, imfs=imfs)
vis.show()



from PyEMD import EEMD

if __name__ == "__main__":
    eemd = EEMD()
    eIMFs = eemd(d1)

eimfs, res = eemd.get_imfs_and_residue()

vis.plot_imfs(imfs=eimfs, residue=res, t=t, include_residue=True)
vis.plot_instant_freq(t, imfs=imfs)
vis.show()

from PyEMD import CEEMDAN

ceemdan = CEEMDAN()

cIMFs = ceemdan(d1)

vis.plot_imfs(imfs=cIMFs, residue=res, t=t, include_residue=True)
vis.plot_instant_freq(t, imfs=imfs)
vis.show()

t = np.arange(0, 3, 0.01)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 11
#       7 imfs, res = emd.get_imfs_and_residue()
#       9 vis = Visualisation()
# ---> 11 vis.plot_imfs(imfs=imfs, residue=res, t=t, include_residue=True)
#      12 vis.plot_instant_freq(t, imfs=imfs)
#      13 vis.show()
#
# NameError: name 't' is not defined
